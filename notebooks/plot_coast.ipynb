# %%
import pygmt
fig = pygmt.Figure()
fig.coast(region=[116, 126, 20.5, 27.5], projection="M12c", shorelines=True, frame=True)
fig.plot(x=[121.6], y=[24.0], style="c0.3c", color="red")
fig.show()
# Out:
# /tmp/ipykernel_3170/2754014870.py:4: FutureWarning: The 'color' parameter has been deprecated since v0.8.0 and will be removed in v0.12.0. Please use 'fill' instead.
#   fig.plot(x=[121.6], y=[24.0], style="c0.3c", color="red")
